# %% [markdown]
# # Udacity Data Engineering Capstone Project

# %% [markdown]
# ## Extract public Gapminder data

# %% [markdown]
# ### Web scraping for Gapminder data

# %%
import os
import pandas as pd
import numpy as np
import json
import re
import requests
from bs4 import BeautifulSoup

# %%
# Download and parse the HTML
start_url = 'https://github.com/Gapminder/gapminder-offline/tree/development/ddf--gapminder--systema_globalis'

# %%
# Download the HTML from start_url
downloaded_html = requests.get(start_url)

# %%
# Parse the HTML with BeautifulSoup and create a soup object
soup = BeautifulSoup(downloaded_html.text)

# %%
# Get list of links from github page
links_with_href = [a['href'] for a in soup.find_all('a', href=True) if a.text]

# %%
url_prefix = 'https://raw.githubusercontent.com/Gapminder/gapminder-offline/'

# %%
def create_file_href_dataframe(links_with_href, url_prefix):
    """
    Populate dataframe with list of CSV files to download from github/Gapminder repository
    
    returns: pandas dataframe
    """
    expr1 = '^.*\.(csv|CSV)$'
    p = re.compile(expr1)
    
    indicator_list = []
    file_href_list = []

    for l in links_with_href:
        b = p.match(l)
        if b:
            file_name = l.split('/')[-1]
            file_href2 = l.split('/')[-2]
            file_href3 = l.split('/')[-3]
            file_href_final = f"{url_prefix}{file_href3}/{file_href2}/{file_name}"
            
            attrs = re.split('--', file_name)
            if len(attrs) >= 3:
                indicator = attrs[2]
                indicator_list.append(indicator)
                file_href_list.append(file_href_final)

    data = {'indicator':indicator_list,
            'file_href':file_href_list}
    df = pd.DataFrame(data)
    return df

# %%
df = create_file_href_dataframe(links_with_href,url_prefix)

# %%
df.head()
# Out:
#                                            indicator  \
# 0                  adults_with_hiv_percent_age_15_49
# 1                          age_at_1st_marriage_women
# 2                 aged_15_24_employment_rate_percent
# 3               aged_15_24_unemployment_rate_percent
# 4  aged_15_64_labour_force_participation_rate_per...
#
#                                            file_href
# 0  https://raw.githubusercontent.com/Gapminder/ga...
# 1  https://raw.githubusercontent.com/Gapminder/ga...
# 2  https://raw.githubusercontent.com/Gapminder/ga...
# 3  https://raw.githubusercontent.com/Gapminder/ga...
# 4  https://raw.githubusercontent.com/Gapminder/ga...

# %%
df.loc[:,['file_href']]
# Out:
#                                              file_href
# 0    https://raw.githubusercontent.com/Gapminder/ga...
# 1    https://raw.githubusercontent.com/Gapminder/ga...
# 2    https://raw.githubusercontent.com/Gapminder/ga...
# 3    https://raw.githubusercontent.com/Gapminder/ga...
# 4    https://raw.githubusercontent.com/Gapminder/ga...
# ..                                                 ...
# 539  https://raw.githubusercontent.com/Gapminder/ga...
# 540  https://raw.githubusercontent.com/Gapminder/ga...
# 541  https://raw.githubusercontent.com/Gapminder/ga...
# 542  https://raw.githubusercontent.com/Gapminder/ga...
# 543  https://raw.githubusercontent.com/Gapminder/ga...
#
# [544 rows x 1 columns]

# %%
df.set_index('indicator', inplace=True)

# %%
df.head()
# Out:
#                                                                                             file_href
# indicator
# adults_with_hiv_percent_age_15_49                   https://raw.githubusercontent.com/Gapminder/ga...
# age_at_1st_marriage_women                           https://raw.githubusercontent.com/Gapminder/ga...
# aged_15_24_employment_rate_percent                  https://raw.githubusercontent.com/Gapminder/ga...
# aged_15_24_unemployment_rate_percent                https://raw.githubusercontent.com/Gapminder/ga...
# aged_15_64_labour_force_participation_rate_percent  https://raw.githubusercontent.com/Gapminder/ga...

# %% [markdown]
# # Download Gapminder csv files

# %%
#!pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9686 sha256=d65687fb645e8c352e9fd0e0790227a90f5c24a79822abc6728ae18b7b0fb8e8
#   Stored in directory: c:\users\mwalb\appdata\local\pip\cache\wheels\bd\a8\c3\3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget
import csv

# %%
def download_csv_files(url_input_file):
    """
    Reads list of href links to a csv file from the url_input_file. Then download each csv file using wget
    
    args: url_input_file
        csv file containing a list of href urls to a specific csv file
        
    """
    # reading csv file
    with open(url_input_file, 'r', encoding='utf8', newline='') as csv_file:
        # creating a csv reader object
        csv_reader = csv.reader(csv_file)
        next(csv_reader)

        # extracting each data row one by one and download csv file
        for line in csv_reader:
            filename = wget.download(line[1], './data')
            print(f"Downloaded {filename}")

# %%
download_csv_files('remaining_files.csv')
# Out:
# 100% [............................................................................] 478425 / 478425Downloaded ./data/ddf--datapoints--life_expectancy_male--by--geo--time (1).csv
# 100% [............................................................................] 647220 / 647220Downloaded ./data/ddf--datapoints--life_expectancy_years--by--geo--time.csv
# 100% [................................................................................] 8555 / 8555Downloaded ./data/ddf--datapoints--literacy_rate_adult_female_percent_of_females_ages_15_above--by--geo--time.csv
# 100% [................................................................................] 8541 / 8541Downloaded ./data/ddf--datapoints--literacy_rate_adult_male_percent_of_males_ages_15_and_above--by--geo--time.csv
# 100% [................................................................................] 8602 / 8602Downloaded ./data/ddf--datapoints--literacy_rate_adult_total_percent_of_people_ages_15_and_above--by--geo--time.csv
# 100% [................................................................................] 8444 / 8444Downloaded ./data/ddf--datapoints--literacy_rate_youth_female_percent_of_females_ages_15_24--by--geo--time.csv
# 100% [................................................................................] 8446 / 8446Downloaded ./data/ddf--datapoints--literacy_rate_youth_male_percent_of_males_ages_15_24--by--geo--time.csv
# 100% [................................................................................] 8471 / 8471Downloaded ./data/ddf--datapoints--literacy_rate_youth_total_percent_of_people_ages_15_24--by--geo--time.csv
# 100% [..............................................................................] 82426 / 82426Downloaded ./data/ddf--datapoints--liver_cancer_deaths_per_100000_men--by--geo--time.csv
# 100% [..............................................................................] 81230 / 81230Downloaded ./data/ddf--datapoints--liver_cancer_deaths_per_100000_women--by--geo--time.csv
# 100% [..............................................................................] 79021 / 79021Downloaded ./data/ddf--datapoints--liver_cancer_new_cases_per_100000_men--by--geo--time.csv
# 100% [..............................................................................] 77719 / 77719Downloaded ./data/ddf--datapoints--liver_cancer_new_cases_per_100000_women--by--geo--time.csv
# 100% [..............................................................................] 80723 / 80723Downloaded ./data/ddf--datapoints--liver_cancer_number_of_female_deaths--by--geo--time.csv
# 100% [..............................................................................] 81876 / 81876Downloaded ./data/ddf--datapoints--liver_cancer_number_of_male_deaths--by--geo--time.csv
# 100% [..............................................................................] 80626 / 80626Downloaded ./data/ddf--datapoints--liver_cancer_number_of_new_female_cases--by--geo--time.csv
# 100% [..............................................................................] 81791 / 81791Downloaded ./data/ddf--datapoints--liver_cancer_number_of_new_male_cases--by--geo--time.csv
# 100% [..............................................................................] 25185 / 25185Downloaded ./data/ddf--datapoints--long_term_unemployment_rate_percent--by--geo--time.csv
# 100% [............................................................................] 104726 / 104726Downloaded ./data/ddf--datapoints--lung_cancer_deaths_per_100000_men--by--geo--time.csv
# 100% [............................................................................] 100813 / 100813Downloaded ./data/ddf--datapoints--lung_cancer_deaths_per_100000_women--by--geo--time.csv
# 100% [..............................................................................] 81775 / 81775Downloaded ./data/ddf--datapoints--lung_cancer_new_cases_per_100000_men--by--geo--time.csv
# 100% [..............................................................................] 78981 / 78981Downloaded ./data/ddf--datapoints--lung_cancer_new_cases_per_100000_women--by--geo--time.csv
# 100% [..............................................................................] 81639 / 81639Downloaded ./data/ddf--datapoints--lung_cancer_number_of_female_deaths--by--geo--time.csv
# 100% [..............................................................................] 83837 / 83837Downloaded ./data/ddf--datapoints--lung_cancer_number_of_male_deaths--by--geo--time.csv
# 100% [..............................................................................] 81534 / 81534Downloaded ./data/ddf--datapoints--lung_cancer_number_of_new_female_cases--by--geo--time.csv
# 100% [..............................................................................] 83763 / 83763Downloaded ./data/ddf--datapoints--lung_cancer_number_of_new_male_cases--by--geo--time.csv
# 100% [..............................................................................] 23679 / 23679Downloaded ./data/ddf--datapoints--malaria_cases_per_100000_reported--by--geo--time.csv
# 100% [................................................................................] 2362 / 2362Downloaded ./data/ddf--datapoints--malaria_deaths_in_children_1_59_months_per_1000_births--by--geo--time.csv
# 100% [..............................................................................] 69922 / 69922Downloaded ./data/ddf--datapoints--malaria_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 11792 / 11792Downloaded ./data/ddf--datapoints--malaria_deaths_per_100000_reported--by--geo--time.csv
# 100% [..............................................................................] 24193 / 24193Downloaded ./data/ddf--datapoints--malaria_number_of_cases_reported--by--geo--time.csv
# 100% [..............................................................................] 10124 / 10124Downloaded ./data/ddf--datapoints--malaria_number_of_deaths_reported--by--geo--time.csv
# 100% [..............................................................................] 94577 / 94577Downloaded ./data/ddf--datapoints--male_agriculture_workers_percent_of_male_employment--by--geo--time.csv
# 100% [..............................................................................] 35545 / 35545Downloaded ./data/ddf--datapoints--male_family_workers_percent_of_male_employment--by--geo--time.csv
# 100% [..............................................................................] 95474 / 95474Downloaded ./data/ddf--datapoints--male_industry_workers_percent_of_male_employment--by--geo--time.csv
# 100% [..............................................................................] 25049 / 25049Downloaded ./data/ddf--datapoints--male_long_term_unemployment_rate_percent--by--geo--time.csv
# 100% [............................................................................] 513429 / 513429Downloaded ./data/ddf--datapoints--male_population_with_projections--by--geo--time.csv
# 100% [..............................................................................] 31324 / 31324Downloaded ./data/ddf--datapoints--male_salaried_workers_percent_of_non_agricultural_male_employment--by--geo--time.csv
# 100% [..............................................................................] 95967 / 95967Downloaded ./data/ddf--datapoints--male_self_employed_percent_of_male_employment--by--geo--time.csv
# 100% [..............................................................................] 96080 / 96080Downloaded ./data/ddf--datapoints--male_service_workers_percent_of_male_employment--by--geo--time.csv
# 100% [..............................................................................] 96281 / 96281Downloaded ./data/ddf--datapoints--males_aged_15_24_employment_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 36122 / 36122Downloaded ./data/ddf--datapoints--males_aged_15_24_unemployment_rate_percent--by--geo--time.csv
# 100% [............................................................................] 123345 / 123345Downloaded ./data/ddf--datapoints--males_aged_15_64_labour_force_participation_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 96298 / 96298Downloaded ./data/ddf--datapoints--males_aged_15plus_employment_rate_percent--by--geo--time.csv
# 100% [............................................................................] 123355 / 123355Downloaded ./data/ddf--datapoints--males_aged_15plus_labour_force_participation_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 46833 / 46833Downloaded ./data/ddf--datapoints--males_aged_15plus_unemployment_rate_percent--by--geo--time.csv
# 100% [............................................................................] 123344 / 123344Downloaded ./data/ddf--datapoints--males_aged_25_54_labour_force_participation_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 34828 / 34828Downloaded ./data/ddf--datapoints--males_aged_25_54_unemployment_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 33713 / 33713Downloaded ./data/ddf--datapoints--males_aged_55_64_unemployment_rate_percent--by--geo--time.csv
# 100% [............................................................................] 120211 / 120211Downloaded ./data/ddf--datapoints--males_aged_65plus_labour_force_participation_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 23290 / 23290Downloaded ./data/ddf--datapoints--males_aged_65plus_unemployment_rate_percent--by--geo--time.csv
# 100% [..............................................................................] 11061 / 11061Downloaded ./data/ddf--datapoints--malnutrition_weight_for_age_percent_of_children_under_5--by--geo--time.csv
# 100% [..............................................................................] 37552 / 37552Downloaded ./data/ddf--datapoints--market_value_of_listed_companies_percent_of_gdp--by--geo--time.csv
# 100% [................................................................................] 7988 / 7988Downloaded ./data/ddf--datapoints--maternal_deaths_lifetime_risk_per_1000--by--geo--time.csv
# 100% [..............................................................................] 31105 / 31105Downloaded ./data/ddf--datapoints--maternal_deaths_total_number--by--geo--time.csv
# 100% [..............................................................................] 32385 / 32385Downloaded ./data/ddf--datapoints--maternal_mortality_ratio_per_100000_live_births--by--geo--time.csv
# 100% [..............................................................................] 11134 / 11134Downloaded ./data/ddf--datapoints--maternal_mortality_ratio_who--by--geo--time.csv
# 100% [..................................................................................] 998 / 998Downloaded ./data/ddf--datapoints--math_achievement_4th_grade--by--geo--time.csv
# 100% [................................................................................] 1609 / 1609Downloaded ./data/ddf--datapoints--math_achievement_8th_grade--by--geo--time.csv
# 100% [..............................................................................] 66370 / 66370Downloaded ./data/ddf--datapoints--mcv_immunized_percent_of_one_year_olds--by--geo--time.csv
# 100% [............................................................................] 121906 / 121906Downloaded ./data/ddf--datapoints--mean_years_in_school_men_15_to_24_years--by--geo--time.csv
# 100% [............................................................................] 122330 / 122330Downloaded ./data/ddf--datapoints--mean_years_in_school_men_25_to_34_years--by--geo--time.csv
# 100% [..............................................................................] 90716 / 90716Downloaded ./data/ddf--datapoints--mean_years_in_school_men_25_years_and_older--by--geo--time.csv
# 100% [............................................................................] 121952 / 121952Downloaded ./data/ddf--datapoints--mean_years_in_school_men_35_to_44_years--by--geo--time.csv
# 100% [............................................................................] 121616 / 121616Downloaded ./data/ddf--datapoints--mean_years_in_school_men_45_to_54_years--by--geo--time.csv
# 100% [............................................................................] 121120 / 121120Downloaded ./data/ddf--datapoints--mean_years_in_school_men_55_to_64_years--by--geo--time.csv
# 100% [............................................................................] 120729 / 120729Downloaded ./data/ddf--datapoints--mean_years_in_school_men_65_plus_years--by--geo--time.csv
# 100% [............................................................................] 122217 / 122217Downloaded ./data/ddf--datapoints--mean_years_in_school_women_15_to_24_years--by--geo--time.csv
# 100% [............................................................................] 122210 / 122210Downloaded ./data/ddf--datapoints--mean_years_in_school_women_25_to_34_years--by--geo--time.csv
# 100% [..............................................................................] 90618 / 90618Downloaded ./data/ddf--datapoints--mean_years_in_school_women_25_years_and_older--by--geo--time.csv
# 100% [............................................................................] 121826 / 121826Downloaded ./data/ddf--datapoints--mean_years_in_school_women_35_to_44_years--by--geo--time.csv
# 100% [............................................................................] 121258 / 121258Downloaded ./data/ddf--datapoints--mean_years_in_school_women_45_to_54_years--by--geo--time.csv
# 100% [............................................................................] 120811 / 120811Downloaded ./data/ddf--datapoints--mean_years_in_school_women_55_to_64_years--by--geo--time.csv
# 100% [............................................................................] 120420 / 120420Downloaded ./data/ddf--datapoints--mean_years_in_school_women_65_plus_years--by--geo--time.csv
# 100% [..............................................................................] 91307 / 91307Downloaded ./data/ddf--datapoints--mean_years_in_school_women_of_reproductive_age_15_to_44--by--geo--time.csv
# 100% [............................................................................] 156576 / 156576Downloaded ./data/ddf--datapoints--mean_years_in_school_women_percent_men_25_to_34_years--by--geo--time.csv
# 100% [................................................................................] 2354 / 2354Downloaded ./data/ddf--datapoints--measles_deaths_in_children_1_59_months_per_1000_births--by--geo--time.csv
# 100% [..............................................................................] 75411 / 75411Downloaded ./data/ddf--datapoints--measles_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 98883 / 98883Downloaded ./data/ddf--datapoints--median_age_years--by--geo--time.csv
# 100% [..............................................................................] 61271 / 61271Downloaded ./data/ddf--datapoints--medical_doctors_per_1000_people--by--geo--time.csv
# 100% [................................................................................] 2804 / 2804Downloaded ./data/ddf--datapoints--meningitis_deaths_in_children_1_59_months_per_1000_births--by--geo--time.csv
# 100% [..............................................................................] 79766 / 79766Downloaded ./data/ddf--datapoints--meningitis_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [............................................................................] 158659 / 158659Downloaded ./data/ddf--datapoints--merchandise_trade_percent_of_gdp--by--geo--time.csv
# 100% [............................................................................] 116732 / 116732Downloaded ./data/ddf--datapoints--military_expenditure_percent_of_gdp--by--geo--time.csv
# 100% [..............................................................................] 73502 / 73502Downloaded ./data/ddf--datapoints--motorcycle_deaths_per_100000_people--by--geo--time.csv
# 100% [................................................................................] 9340 / 9340Downloaded ./data/ddf--datapoints--multisector_cross_cutting_aid_given_percent_of_aid--by--geo--time.csv
# 100% [..............................................................................] 11557 / 11557Downloaded ./data/ddf--datapoints--municipal_water_withdrawal_cu_meters_per_person--by--geo--time.csv
# 100% [................................................................................] 7954 / 7954Downloaded ./data/ddf--datapoints--municipal_water_withdrawal_percent_of_total--by--geo--time.csv
# 100% [..............................................................................] 50975 / 50975Downloaded ./data/ddf--datapoints--murder_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 82214 / 82214Downloaded ./data/ddf--datapoints--murder_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 53031 / 53031Downloaded ./data/ddf--datapoints--murdered_15_29_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 53096 / 53096Downloaded ./data/ddf--datapoints--murdered_30_44_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 52127 / 52127Downloaded ./data/ddf--datapoints--murdered_45_59_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 47911 / 47911Downloaded ./data/ddf--datapoints--murdered_60plus_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 48064 / 48064Downloaded ./data/ddf--datapoints--murdered_children_0_14_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 50839 / 50839Downloaded ./data/ddf--datapoints--murdered_men_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 49196 / 49196Downloaded ./data/ddf--datapoints--murdered_women_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 37300 / 37300Downloaded ./data/ddf--datapoints--natural_gas_production_per_person--by--geo--time.csv
# 100% [..............................................................................] 38467 / 38467Downloaded ./data/ddf--datapoints--natural_gas_production_total--by--geo--time.csv
# 100% [..............................................................................] 34832 / 34832Downloaded ./data/ddf--datapoints--natural_gas_proved_reserves_total--by--geo--time.csv
# 100% [..............................................................................] 32298 / 32298Downloaded ./data/ddf--datapoints--natural_gas_proven_reserves_per_person--by--geo--time.csv
# 100% [................................................................................] 2723 / 2723Downloaded ./data/ddf--datapoints--ncd_deaths_in_children_1_59_months_per_1000_births--by--geo--time.csv
# 100% [..............................................................................] 84714 / 84714Downloaded ./data/ddf--datapoints--ncd_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 91000 / 91000Downloaded ./data/ddf--datapoints--net_barter_terms_of_trade_2000_100--by--geo--time.csv
# 100% [............................................................................] 654080 / 654080Downloaded ./data/ddf--datapoints--new_births_total_number_estimated--by--geo--time.csv
# 100% [............................................................................] 117703 / 117703Downloaded ./data/ddf--datapoints--newborn_deaths--by--geo--time.csv
# 100% [............................................................................] 115085 / 115085Downloaded ./data/ddf--datapoints--newborn_mortality_rate_per_1000--by--geo--time.csv
# 100% [..............................................................................] 21985 / 21985Downloaded ./data/ddf--datapoints--newly_hiv_infected_number_all_ages--by--geo--time.csv
# 100% [..............................................................................] 21549 / 21549Downloaded ./data/ddf--datapoints--newly_hiv_infected_percent_age_15_49--by--geo--time.csv
# 100% [..............................................................................] 17832 / 17832Downloaded ./data/ddf--datapoints--nuclear_power_generation_per_person--by--geo--time.csv
# 100% [..............................................................................] 63539 / 63539Downloaded ./data/ddf--datapoints--nuclear_power_generation_total--by--geo--time.csv
# 100% [............................................................................] 589651 / 589651Downloaded ./data/ddf--datapoints--number_of_child_deaths--by--geo--time.csv
# 100% [..............................................................................] 16948 / 16948Downloaded ./data/ddf--datapoints--number_of_people_in_poverty--by--geo--time.csv
# 100% [..............................................................................] 56444 / 56444Downloaded ./data/ddf--datapoints--oil_consumption_per_cap--by--geo--time.csv
# 100% [..............................................................................] 59195 / 59195Downloaded ./data/ddf--datapoints--oil_consumption_total--by--geo--time.csv
# 100% [..............................................................................] 38562 / 38562Downloaded ./data/ddf--datapoints--oil_production_per_person--by--geo--time.csv
# 100% [..............................................................................] 40346 / 40346Downloaded ./data/ddf--datapoints--oil_production_total--by--geo--time.csv
# 100% [..............................................................................] 33156 / 33156Downloaded ./data/ddf--datapoints--oil_proved_reserves_total--by--geo--time.csv
# 100% [..............................................................................] 30890 / 30890Downloaded ./data/ddf--datapoints--oil_proven_reserves_per_person--by--geo--time.csv
# 100% [................................................................................] 2778 / 2778Downloaded ./data/ddf--datapoints--other_deaths_in_newborn_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2305 / 2305Downloaded ./data/ddf--datapoints--other_deaths_in_newborn_total_deaths--by--geo--time.csv
# 100% [................................................................................] 2780 / 2780Downloaded ./data/ddf--datapoints--other_infections_deaths_in_children_1_59_months_per_1000_birt--by--geo--time.csv
# 100% [................................................................................] 2389 / 2389Downloaded ./data/ddf--datapoints--other_infections_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 10488 / 10488Downloaded ./data/ddf--datapoints--other_social_services_aid_given_percent_of_aid--by--geo--time.csv
# 100% [..............................................................................] 35228 / 35228Downloaded ./data/ddf--datapoints--out_of_pocket_share_of_total_health_spending_percent--by--geo--time.csv
# 100% [..............................................................................] 34558 / 34558Downloaded ./data/ddf--datapoints--pab_immunized_percent_of_newborns--by--geo--time.csv
# 100% [..............................................................................] 27147 / 27147Downloaded ./data/ddf--datapoints--patent_applications_total--by--geo--time.csv
# 100% [..............................................................................] 22312 / 22312Downloaded ./data/ddf--datapoints--patents_granted_total--by--geo--time.csv
# 100% [..............................................................................] 16300 / 16300Downloaded ./data/ddf--datapoints--patents_in_force_total--by--geo--time.csv
# 100% [..............................................................................] 48601 / 48601Downloaded ./data/ddf--datapoints--people_living_with_hiv_number_all_ages--by--geo--time.csv
# 100% [..............................................................................] 31191 / 31191Downloaded ./data/ddf--datapoints--personal_computers_per_100_people--by--geo--time.csv
# 100% [..............................................................................] 34795 / 34795Downloaded ./data/ddf--datapoints--personal_computers_total--by--geo--time.csv
# 100% [................................................................................] 2554 / 2554Downloaded ./data/ddf--datapoints--pertussis_deaths_in_children_1_59_months_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2175 / 2175Downloaded ./data/ddf--datapoints--pertussis_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 57362 / 57362Downloaded ./data/ddf--datapoints--plane_crash_affected_annual_number--by--geo--time.csv
# 100% [..............................................................................] 57325 / 57325Downloaded ./data/ddf--datapoints--plane_crash_deaths_annual_number--by--geo--time.csv
# 100% [..............................................................................] 83291 / 83291Downloaded ./data/ddf--datapoints--planted_forest_area_ha--by--geo--time.csv
# 100% [................................................................................] 2761 / 2761Downloaded ./data/ddf--datapoints--pneumonia_deaths_in_children_1_59_months_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2374 / 2374Downloaded ./data/ddf--datapoints--pneumonia_deaths_in_children_1_59_months_total_deaths--by--geo--time.csv
# 100% [................................................................................] 2752 / 2752Downloaded ./data/ddf--datapoints--pneumonia_deaths_in_newborn_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2273 / 2273Downloaded ./data/ddf--datapoints--pneumonia_deaths_in_newborn_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 73037 / 73037Downloaded ./data/ddf--datapoints--poisonings_deaths_per_100000_people--by--geo--time.csv
# 100% [............................................................................] 107596 / 107596Downloaded ./data/ddf--datapoints--population_aged_0_4_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 107502 / 107502Downloaded ./data/ddf--datapoints--population_aged_0_4_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 107644 / 107644Downloaded ./data/ddf--datapoints--population_aged_0_4_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 100600 / 100600Downloaded ./data/ddf--datapoints--population_aged_0_4_years_total_number--by--geo--time.csv
# 100% [............................................................................] 107322 / 107322Downloaded ./data/ddf--datapoints--population_aged_10_14_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 107280 / 107280Downloaded ./data/ddf--datapoints--population_aged_10_14_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 107376 / 107376Downloaded ./data/ddf--datapoints--population_aged_10_14_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 100392 / 100392Downloaded ./data/ddf--datapoints--population_aged_10_14_years_total_number--by--geo--time.csv
# 100% [............................................................................] 106773 / 106773Downloaded ./data/ddf--datapoints--population_aged_15_19_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 106575 / 106575Downloaded ./data/ddf--datapoints--population_aged_15_19_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 106866 / 106866Downloaded ./data/ddf--datapoints--population_aged_15_19_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 100286 / 100286Downloaded ./data/ddf--datapoints--population_aged_15_19_years_total_number--by--geo--time.csv
# 100% [............................................................................] 111385 / 111385Downloaded ./data/ddf--datapoints--population_aged_20_39_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 111362 / 111362Downloaded ./data/ddf--datapoints--population_aged_20_39_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 111321 / 111321Downloaded ./data/ddf--datapoints--population_aged_20_39_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 103942 / 103942Downloaded ./data/ddf--datapoints--population_aged_20_39_years_total_number--by--geo--time.csv
# 100% [............................................................................] 111377 / 111377Downloaded ./data/ddf--datapoints--population_aged_40_59_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 111317 / 111317Downloaded ./data/ddf--datapoints--population_aged_40_59_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 111260 / 111260Downloaded ./data/ddf--datapoints--population_aged_40_59_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 103111 / 103111Downloaded ./data/ddf--datapoints--population_aged_40_59_years_total_number--by--geo--time.csv
# 100% [............................................................................] 107482 / 107482Downloaded ./data/ddf--datapoints--population_aged_5_9_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 107419 / 107419Downloaded ./data/ddf--datapoints--population_aged_5_9_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 107501 / 107501Downloaded ./data/ddf--datapoints--population_aged_5_9_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 100480 / 100480Downloaded ./data/ddf--datapoints--population_aged_5_9_years_total_number--by--geo--time.csv
# 100% [............................................................................] 108757 / 108757Downloaded ./data/ddf--datapoints--population_aged_60plus_years_both_sexes_percent--by--geo--time.csv
# 100% [............................................................................] 108919 / 108919Downloaded ./data/ddf--datapoints--population_aged_60plus_years_female_percent--by--geo--time.csv
# 100% [............................................................................] 108606 / 108606Downloaded ./data/ddf--datapoints--population_aged_60plus_years_male_percent--by--geo--time.csv
# 100% [............................................................................] 101836 / 101836Downloaded ./data/ddf--datapoints--population_aged_60plus_years_total_number--by--geo--time.csv
# 100% [............................................................................] 634502 / 634502Downloaded ./data/ddf--datapoints--population_density_per_square_km--by--geo--time.csv
# 100% [............................................................................] 212352 / 212352Downloaded ./data/ddf--datapoints--population_growth_annual_percent--by--geo--time.csv
# 100% [............................................................................] 455601 / 455601Downloaded ./data/ddf--datapoints--population_growth_annual_percent_with_projections--by--geo--time.csv
# 100% [............................................................................] 123135 / 123135Downloaded ./data/ddf--datapoints--population_in_urban_agglomerations_m_1_million_percent_of_total--by--geo--time.csv
# 100% [................................................................................] 5902 / 5902Downloaded ./data/ddf--datapoints--population_policies_aid_given_percent_of_aid--by--geo--time.csv
# 100% [............................................................................] 995968 / 995968Downloaded ./data/ddf--datapoints--population_total--by--geo--time.csv
# 100% [..............................................................................] 18579 / 18579Downloaded ./data/ddf--datapoints--poverty_percent_people_below_320_a_day--by--geo--time.csv
# 100% [..............................................................................] 18857 / 18857Downloaded ./data/ddf--datapoints--poverty_percent_people_below_550_a_day--by--geo--time.csv
# 100% [................................................................................] 2731 / 2731Downloaded ./data/ddf--datapoints--prematurity_deaths_in_newborn_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2406 / 2406Downloaded ./data/ddf--datapoints--prematurity_deaths_in_newborn_total_deaths--by--geo--time.csv
# 100% [................................................................................] 2089 / 2089Downloaded ./data/ddf--datapoints--present_value_of_debt_percent_of_gni--by--geo--time.csv
# 100% [..............................................................................] 81120 / 81120Downloaded ./data/ddf--datapoints--primary_completion_rate_total_percent_of_relevant_age_group--by--geo--time.csv
# 100% [..............................................................................] 78803 / 78803Downloaded ./data/ddf--datapoints--primary_forest_area_ha--by--geo--time.csv
# 100% [..............................................................................] 71956 / 71956Downloaded ./data/ddf--datapoints--primary_school_completion_percent_of_boys--by--geo--time.csv
# 100% [..............................................................................] 71925 / 71925Downloaded ./data/ddf--datapoints--primary_school_completion_percent_of_girls--by--geo--time.csv
# 100% [..............................................................................] 45259 / 45259Downloaded ./data/ddf--datapoints--private_share_of_total_health_spending_percent--by--geo--time.csv
# 100% [..............................................................................] 10735 / 10735Downloaded ./data/ddf--datapoints--privately_owned_forest_land_percent--by--geo--time.csv
# 100% [................................................................................] 1178 / 1178Downloaded ./data/ddf--datapoints--privately_owned_other_wooded_land_percent--by--geo--time.csv
# 100% [..............................................................................] 11126 / 11126Downloaded ./data/ddf--datapoints--production_sector_aid_given_percent_of_aid--by--geo--time.csv
# 100% [............................................................................] 104265 / 104265Downloaded ./data/ddf--datapoints--prostate_cancer_deaths_per_100000_men--by--geo--time.csv
# 100% [..............................................................................] 82977 / 82977Downloaded ./data/ddf--datapoints--prostate_cancer_new_cases_per_100000_men--by--geo--time.csv
# 100% [..............................................................................] 82809 / 82809Downloaded ./data/ddf--datapoints--prostate_cancer_number_of_male_deaths--by--geo--time.csv
# 100% [..............................................................................] 83979 / 83979Downloaded ./data/ddf--datapoints--prostate_cancer_number_of_new_male_cases--by--geo--time.csv
# 100% [..............................................................................] 25798 / 25798Downloaded ./data/ddf--datapoints--pump_price_for_gasoline_us_per_liter--by--geo--time.csv
# 100% [..............................................................................] 88090 / 88090Downloaded ./data/ddf--datapoints--ratio_of_girls_to_boys_in_primary_and_secondary_education_perc--by--geo--time.csv
# 100% [................................................................................] 7667 / 7667Downloaded ./data/ddf--datapoints--ratio_of_young_literate_females_to_males_percent_ages_15_24--by--geo--time.csv
# 100% [..............................................................................] 29411 / 29411Downloaded ./data/ddf--datapoints--renewable_water_cu_meters_per_person--by--geo--time.csv
# 100% [..............................................................................] 68657 / 68657Downloaded ./data/ddf--datapoints--residential_electricity_use_per_person--by--geo--time.csv
# 100% [..............................................................................] 93949 / 93949Downloaded ./data/ddf--datapoints--residential_electricity_use_total--by--geo--time.csv
# 100% [..............................................................................] 78701 / 78701Downloaded ./data/ddf--datapoints--residential_energy_use_percent--by--geo--time.csv
# 100% [..............................................................................] 28369 / 28369Downloaded ./data/ddf--datapoints--roads_paved_percent_of_total_roads--by--geo--time.csv
# 100% [................................................................................] 5480 / 5480Downloaded ./data/ddf--datapoints--rural_poverty_percent_rural_people_below_national_rural--by--geo--time.csv
# 100% [..............................................................................] 32835 / 32835Downloaded ./data/ddf--datapoints--salaried_workers_percent_of_non_agricultural_employment--by--geo--time.csv
# 100% [..............................................................................] 95803 / 95803Downloaded ./data/ddf--datapoints--self_employed_percent_of_employment--by--geo--time.csv
# 100% [................................................................................] 2776 / 2776Downloaded ./data/ddf--datapoints--sepsis_deaths_in_newborn_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2287 / 2287Downloaded ./data/ddf--datapoints--sepsis_deaths_in_newborn_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 56526 / 56526Downloaded ./data/ddf--datapoints--service_workers_percent_of_employment--by--geo--time.csv
# 100% [............................................................................] 113761 / 113761Downloaded ./data/ddf--datapoints--services_percent_of_gdp--by--geo--time.csv
# 100% [............................................................................] 117172 / 117172Downloaded ./data/ddf--datapoints--sex_ratio_0_14_years--by--geo--time.csv
# 100% [............................................................................] 116632 / 116632Downloaded ./data/ddf--datapoints--sex_ratio_15_24_years--by--geo--time.csv
# 100% [............................................................................] 115622 / 115622Downloaded ./data/ddf--datapoints--sex_ratio_15_49_years--by--geo--time.csv
# 100% [............................................................................] 112026 / 112026Downloaded ./data/ddf--datapoints--sex_ratio_above_50_years--by--geo--time.csv
# 100% [............................................................................] 113547 / 113547Downloaded ./data/ddf--datapoints--sex_ratio_all_age_groups--by--geo--time.csv
# 100% [................................................................................] 3582 / 3582Downloaded ./data/ddf--datapoints--smoking_adults_percent_of_population_over_age_15--by--geo--time.csv
# 100% [................................................................................] 3674 / 3674Downloaded ./data/ddf--datapoints--smoking_men_percent_of_men_over_age_15--by--geo--time.csv
# 100% [................................................................................] 5287 / 5287Downloaded ./data/ddf--datapoints--smoking_women_percent_of_women_over_age_15--by--geo--time.csv
# 100% [................................................................................] 4843 / 4843Downloaded ./data/ddf--datapoints--stillbirths_per_1000_births--by--geo--time.csv
# 100% [............................................................................] 103529 / 103529Downloaded ./data/ddf--datapoints--stomach_cancer_deaths_per_100000_men--by--geo--time.csv
# 100% [............................................................................] 101322 / 101322Downloaded ./data/ddf--datapoints--stomach_cancer_deaths_per_100000_women--by--geo--time.csv
# 100% [..............................................................................] 81514 / 81514Downloaded ./data/ddf--datapoints--stomach_cancer_new_cases_per_100000_men--by--geo--time.csv
# 100% [..............................................................................] 79152 / 79152Downloaded ./data/ddf--datapoints--stomach_cancer_new_cases_per_100000_women--by--geo--time.csv
# 100% [..............................................................................] 81866 / 81866Downloaded ./data/ddf--datapoints--stomach_cancer_number_of_female_deaths--by--geo--time.csv
# 100% [..............................................................................] 82537 / 82537Downloaded ./data/ddf--datapoints--stomach_cancer_number_of_male_deaths--by--geo--time.csv
# 100% [..............................................................................] 81853 / 81853Downloaded ./data/ddf--datapoints--stomach_cancer_number_of_new_female_cases--by--geo--time.csv
# 100% [..............................................................................] 82715 / 82715Downloaded ./data/ddf--datapoints--stomach_cancer_number_of_new_male_cases--by--geo--time.csv
# 100% [..............................................................................] 80794 / 80794Downloaded ./data/ddf--datapoints--storm_affected_annual_number--by--geo--time.csv
# 100% [..............................................................................] 78262 / 78262Downloaded ./data/ddf--datapoints--storm_deaths_annual_number--by--geo--time.csv
# 100% [............................................................................] 284384 / 284384Downloaded ./data/ddf--datapoints--subsistence_incomes_per_person--by--geo--time.csv
# 100% [............................................................................] 129039 / 129039Downloaded ./data/ddf--datapoints--sugar_per_person_g_per_day--by--geo--time.csv
# 100% [..............................................................................] 43623 / 43623Downloaded ./data/ddf--datapoints--suicide_age_0_14_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 55267 / 55267Downloaded ./data/ddf--datapoints--suicide_age_15_29_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 55876 / 55876Downloaded ./data/ddf--datapoints--suicide_age_30_44_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 55581 / 55581Downloaded ./data/ddf--datapoints--suicide_age_45_59_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 51983 / 51983Downloaded ./data/ddf--datapoints--suicide_age_60plus_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 53377 / 53377Downloaded ./data/ddf--datapoints--suicide_men_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 52808 / 52808Downloaded ./data/ddf--datapoints--suicide_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 83934 / 83934Downloaded ./data/ddf--datapoints--suicide_total_deaths--by--geo--time.csv
# 100% [..............................................................................] 50440 / 50440Downloaded ./data/ddf--datapoints--suicide_women_per_100000_people--by--geo--time.csv
# 100% [............................................................................] 423690 / 423690Downloaded ./data/ddf--datapoints--sulfur_emissions_per_person_kg--by--geo--time.csv
# 100% [............................................................................] 184358 / 184358Downloaded ./data/ddf--datapoints--surface_area_sq_km--by--geo--time.csv
# 100% [............................................................................] 501056 / 501056Downloaded ./data/ddf--datapoints--surviving_kids_per_woman--by--geo--time.csv
# 100% [..............................................................................] 69202 / 69202Downloaded ./data/ddf--datapoints--tax_revenue_percent_of_gdp--by--geo--time.csv
# 100% [..............................................................................] 28850 / 28850Downloaded ./data/ddf--datapoints--tb_programme_dots_population_coverage_percent--by--geo--time.csv
# 100% [..............................................................................] 35095 / 35095Downloaded ./data/ddf--datapoints--tb_with_hivplus_deaths_per_100000_estimated--by--geo--time.csv
# 100% [..............................................................................] 42621 / 42621Downloaded ./data/ddf--datapoints--tb_with_hivplus_existing_cases_per_100000_estimated--by--geo--time.csv
# 100% [..............................................................................] 42587 / 42587Downloaded ./data/ddf--datapoints--tb_with_hivplus_new_cases_per_100000_estimated--by--geo--time.csv
# 100% [..............................................................................] 34533 / 34533Downloaded ./data/ddf--datapoints--tb_with_hivplus_number_of_deaths_estimated--by--geo--time.csv
# 100% [..............................................................................] 41770 / 41770Downloaded ./data/ddf--datapoints--tb_with_hivplus_number_of_existing_cases_estimated--by--geo--time.csv
# 100% [..............................................................................] 41873 / 41873Downloaded ./data/ddf--datapoints--tb_with_hivplus_number_of_new_cases_estimated--by--geo--time.csv
# 100% [..............................................................................] 80619 / 80619Downloaded ./data/ddf--datapoints--teen_fertility_rate_births_per_1000_women_ages_15_19--by--geo--time.csv
# 100% [................................................................................] 2506 / 2506Downloaded ./data/ddf--datapoints--tetanus_deaths_in_newborn_per_1000_births--by--geo--time.csv
# 100% [................................................................................] 2150 / 2150Downloaded ./data/ddf--datapoints--tetanus_deaths_in_newborn_total_deaths--by--geo--time.csv
# 100% [............................................................................] 924476 / 924476Downloaded ./data/ddf--datapoints--total_gdp_ppp_inflation_adjusted--by--geo--time.csv
# 100% [............................................................................] 234621 / 234621Downloaded ./data/ddf--datapoints--total_gdp_us_inflation_adjusted--by--geo--time.csv
# 100% [............................................................................] 133639 / 133639Downloaded ./data/ddf--datapoints--total_gni_ppp_current_international--by--geo--time.csv
# 100% [..............................................................................] 44569 / 44569Downloaded ./data/ddf--datapoints--total_health_spending_per_person_international_dollar--by--geo--time.csv
# 100% [..............................................................................] 44279 / 44279Downloaded ./data/ddf--datapoints--total_health_spending_per_person_us--by--geo--time.csv
# 100% [..............................................................................] 45269 / 45269Downloaded ./data/ddf--datapoints--total_health_spending_percent_of_gdp--by--geo--time.csv
# 100% [..............................................................................] 11757 / 11757Downloaded ./data/ddf--datapoints--total_number_of_dollar_billionaires--by--geo--time.csv
# 100% [............................................................................] 372471 / 372471Downloaded ./data/ddf--datapoints--total_population_with_projections--by--geo--time.csv
# 100% [..............................................................................] 75047 / 75047Downloaded ./data/ddf--datapoints--total_reserves_percent_of_debt_to_foreigners--by--geo--time.csv
# 100% [............................................................................] 421678 / 421678Downloaded ./data/ddf--datapoints--total_sulfur_emission_kilotonnes--by--geo--time.csv
# 100% [................................................................................] 9544 / 9544Downloaded ./data/ddf--datapoints--total_water_withdrawal_billion_cu_meters--by--geo--time.csv
# 100% [............................................................................] 151002 / 151002Downloaded ./data/ddf--datapoints--trade_balance_percent_of_gdp--by--geo--time.csv
# 100% [............................................................................] 209400 / 209400Downloaded ./data/ddf--datapoints--trade_balance_us_not_inflation_adjusted--by--geo--time.csv
# 100% [..............................................................................] 52273 / 52273Downloaded ./data/ddf--datapoints--traffic_deaths_men_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 51867 / 51867Downloaded ./data/ddf--datapoints--traffic_deaths_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 49492 / 49492Downloaded ./data/ddf--datapoints--traffic_deaths_women_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 54926 / 54926Downloaded ./data/ddf--datapoints--traffic_mortality_15_29_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 53930 / 53930Downloaded ./data/ddf--datapoints--traffic_mortality_30_44_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 53797 / 53797Downloaded ./data/ddf--datapoints--traffic_mortality_45_59_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 51536 / 51536Downloaded ./data/ddf--datapoints--traffic_mortality_60plus_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 51589 / 51589Downloaded ./data/ddf--datapoints--traffic_mortality_children_0_14_per_100000_people--by--geo--time.csv
# 100% [..............................................................................] 13575 / 13575Downloaded ./data/ddf--datapoints--traffic_total_deaths--by--geo--time.csv
# 100% [..................................................................................] 365 / 365Downloaded ./data/ddf--datapoints--tsunami_affected_annual_number--by--geo--time.csv
# 100% [..................................................................................] 314 / 314Downloaded ./data/ddf--datapoints--tsunami_deaths_annual_number--by--geo--time.csv
# 100% [............................................................................] 138602 / 138602Downloaded ./data/ddf--datapoints--under_five_mortality_from_cme_per_1000_born--by--geo--time.csv
# 100% [............................................................................] 110429 / 110429Downloaded ./data/ddf--datapoints--under_five_mortality_from_ihme_per_1000_born--by--geo--time.csv
# 100% [................................................................................] 4499 / 4499Downloaded ./data/ddf--datapoints--underweight_children--by--geo--time.csv
# 100% [............................................................................] 205334 / 205334Downloaded ./data/ddf--datapoints--urban_population--by--geo--time.csv
# 100% [............................................................................] 210464 / 210464Downloaded ./data/ddf--datapoints--urban_population_growth_annual_percent--by--geo--time.csv
# 100% [............................................................................] 195621 / 195621Downloaded ./data/ddf--datapoints--urban_population_percent_of_total--by--geo--time.csv
# 100% [................................................................................] 5628 / 5628Downloaded ./data/ddf--datapoints--urban_poverty_percent_urban_people_below_national_urban--by--geo--time.csv
# 100% [................................................................................] 9496 / 9496Downloaded ./data/ddf--datapoints--water_and_sanitation_aid_given_percent_of_aid--by--geo--time.csv
# 100% [................................................................................] 9506 / 9506Downloaded ./data/ddf--datapoints--water_withdrawal_cu_meters_per_person--by--geo--time.csv
# 100% [..............................................................................] 67114 / 67114Downloaded ./data/ddf--datapoints--wood_removal_cubic_meters--by--geo--time.csv
# 100% [..............................................................................] 27420 / 27420Downloaded ./data/ddf--datapoints--working_hours_per_week--by--geo--time.csv
# 100% [............................................................................] 346550 / 346550Downloaded ./data/ddf--datapoints--yearly_co2_emissions_1000_tonnes--by--geo--time.csv
# 100% [..............................................................................] 48906 / 48906Downloaded ./data/ddf--entities--geo--country.csv
# 100% [..................................................................................] 133 / 133Downloaded ./data/ddf--entities--geo--g77_and_oecd_countries.csv
# 100% [..................................................................................] 120 / 120Downloaded ./data/ddf--entities--geo--global.csv
# 100% [..................................................................................] 221 / 221Downloaded ./data/ddf--entities--geo--income_groups.csv
# 100% [..................................................................................] 107 / 107Downloaded ./data/ddf--entities--geo--landlocked.csv
# 100% [..................................................................................] 163 / 163Downloaded ./data/ddf--entities--geo--main_religion_2008.csv
# 100% [................................................................................] 9722 / 9722Downloaded ./data/ddf--entities--geo--world_4region.csv
# 100% [..............................................................................] 36744 / 36744Downloaded ./data/ddf--entities--geo--world_6region.csv
# 100% [................................................................................] 3192 / 3192Downloaded ./data/ddf--entities--tag.csv
