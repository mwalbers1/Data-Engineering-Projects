# %% [markdown]
# # Covid-19 Data Gathering

# %%
import os
import pandas as pd
import numpy as np
import json
import re
import requests
from bs4 import BeautifulSoup

# %%
from web_scraping.data_extraction import download_csv_file, get_links_from_page, get_filename_href

# %%
url_prefix = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/'

# %%
start_url = 'https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports/'

# %%
# Download and parse the HTML
href_list = get_links_from_page(start_url)

# %%
#for index, t in enumerate(get_filename_href(href_list, url_prefix)):
#    download_csv_file(t[1])
# Out:
# 100% [............................................................................] 566338 / 566338Downloaded ./data/01-01-2021.csv
# 100% [............................................................................] 566661 / 566661Downloaded ./data/01-02-2021.csv
# 100% [............................................................................] 566725 / 566725Downloaded ./data/01-03-2021.csv
# 100% [............................................................................] 566763 / 566763Downloaded ./data/01-04-2021.csv
# 100% [............................................................................] 566975 / 566975Downloaded ./data/01-05-2021.csv
# 100% [............................................................................] 566992 / 566992Downloaded ./data/01-06-2021.csv
# 100% [............................................................................] 567041 / 567041Downloaded ./data/01-07-2021.csv
# ...
